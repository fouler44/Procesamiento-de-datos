# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Librerias para operaciones de regresión lineal
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("./CopierSalesofAmerica.csv")

# %%
# Determinen la cantidad de filas y columnas del archivo
data.shape
# Out:
# (10, 3)

# %%
# Mostrar la tabla
data.head()
# Out:
#   Representante  llamadas  ventas
# 0    Tom Keller        20      30
# 1     Jeff Hall        40      60
# 2  Brian Virost        20      40
# 3     Greg Fish        30      60
# 4   Susan Welch        10      30

# %%
# Seleccionar los datos para determinar el coeficiente de correlación
X_train = np.array(data['llamadas']).reshape(-1, 1)
y_train = np.array(data['ventas'])

# %%
# Calcular el coeficiente de correlación lineal
r = linear_model.LinearRegression()

# Entrenando el modelo de los datos
r.fit(X_train, y_train)

# Obtener las predicciones
# Valores para y
y_pred = r.predict(X_train)

print(f'Coeficiente de correlación: {r.coef_}')
print(f'Interseccion: {r.intercept_}')
print(f'Error cuadrática de la media: {mean_squared_error(y_train, y_pred)}')
print(f'Varianza: {r2_score(y_train, y_pred)}')
# Out:
# Coeficiente de correlación: [1.18421053]
# Interseccion: 18.94736842105263
# Error cuadrática de la media: 78.42105263157899
# Varianza: 0.5761024182076812

# %%
# Realizar la gráfica de dispersión y la pendiente
x = X_train.ravel()
plt.figure(figsize=(8,5))
plt.scatter(x, y_train, color='steelblue', s=80, label='Datos')
plt.plot(x, y_pred, color='red', linewidth=3, label='Pendiente')
plt.xlabel('# de llamadas')
plt.ylabel('Copiadoras vendidas')
plt.title('Copier Sales of America')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
