# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pintura.csv')
df = df.drop(columns=["Agente"])

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df["Millas"], df["Llamadas"], df["Comisiones"])

ax.set_xlabel("Millas")
ax.set_ylabel("Llamadas")
ax.set_zlabel("Comisiones")

plt.show()

# %% [markdown]
# Los resultados muestran que tanto las millas recorridas como las llamadas realizadas influyen positivamente en las comisiones. Sin embargo, las millas tienen una relación más fuerte con las ganancias. Esto indica que recorrer más territorio parece estar más asociado con mayores ventas que solo realizar llamadas.

# %%
r_yx1 = df["Comisiones"].corr(df["Millas"])
r_yx2 = df["Comisiones"].corr(df["Llamadas"])
r_x1x2 = df["Millas"].corr(df["Llamadas"])

r_yx1, r_yx2, r_x1x2
# Out:
# (np.float64(0.8322714071792504),
#  np.float64(0.6797156955013891),
#  np.float64(0.40107530341066905))

# %% [markdown]
# Los valores de r confirman lo que se ve en la gráfica. La relación entre comisiones y millas es más fuerte (0.83) que la relación entre comisiones y llamadas (0.68).
#
# En resumen, tanto las millas como las llamadas influyen en las comisiones, pero las millas tienen mayor relación con las ganancias.
